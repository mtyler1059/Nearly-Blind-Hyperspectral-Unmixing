# %% [markdown]
# This notebook should be able to recreate the algorithm

# %%
def algo_2_glu(X, X_hat, A_hat, alpha):
    S_glu = []
    A_glu= []

    return(S_glu,A_glu)

# %%
def algo_3_GRSU(max_itter, eps = 10e-5):
    err = 1
    T = []
    A = []
    S = []
    while(i<max_itter and err>eps):
        T = T

        err = err - 10e-7
        i = i+1
    return S, A
